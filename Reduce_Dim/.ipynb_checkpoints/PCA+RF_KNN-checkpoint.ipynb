# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"E:\file\MachineLearning\sklearn_class\04PCASVD\digit recognizor.csv")
x = data.iloc[:,1:]
y = data.iloc[:,0]
x.shape
# Out:
# (42000, 784)

# %%
pca_line = PCA().fit(x)

# %%
#画出特征个数对信息度保留的影响
plt.figure(figsize=[20,5])
plt.plot(np.cumsum(pca_line.explained_variance_ratio_))
plt.xlabel("number of components after dimension reduction")
plt.ylabel("cumulative explained variance")
plt.show()

# %%
score=[]
for i in range(1,101,10):
    x_dr=PCA(i).fit_transform(x)
    #cv=5交叉验证的次数
    once=cross_val_score(RFC(n_estimators=10,random_state=0),x_dr,y,cv=5).mean()
    score.append(once)
plt.figure(figsize=[20,5])
plt.plot(range(1,101,10),score)
plt.show()

# %%
score=[]
for i in range(10,25):
    x_dr=PCA(i).fit_transform(x)
    #cv=5交叉验证的次数
    once=cross_val_score(RFC(n_estimators=10,random_state=0),x_dr,y,cv=5).mean()
    score.append(once)
plt.figure(figsize=[20,5])
plt.plot(range(10,25),score)
plt.show()

# %%
#取最高时的i=21
x_dr=PCA(21).fit_transform(x)
x_dr.shape
# Out:
# (42000, 21)

# %%
cross_val_score(RFC(n_estimators=10,random_state=0),x_dr,y,cv=5).mean()
# Out:
# 0.9172389088447941

# %%
cross_val_score(RFC(n_estimators=100,random_state=0),x_dr,y,cv=5).mean()
# Out:
# 0.942976268723213

# %%
#换成KNN , 有提升效果
cross_val_score(KNN(),x_dr,y,cv=5).mean()
# Out:
# 0.9676187135790304

# %%
score = []
x_dr = PCA(21).fit_transform(x)
for i in range(10):
    once = cross_val_score(KNN(i+1),x_dr,y,cv=5).mean()
    score.append(once)
plt.figure(figsize=[20,5])
plt.plot(range(10),score)
plt.show()

# %%
#选出 2
cross_val_score(KNN(2),x_dr,y,cv=5).mean()
# Out:
# 0.9597137631519793

# %%
# %%timeit
cross_val_score(KNN(2),x_dr,y,cv=5).mean()
# Out:
# 39.6 s ± 821 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
k=KNN(2).fit(x_dr,y)

# %%
k.predict(x_dr[14].reshape(1,-1)) #注意! 这里需要reshape(1,-1) 将数据转为一行
# Out:
# array([3], dtype=int64)

# %%
y[14]
# Out:
# 3
