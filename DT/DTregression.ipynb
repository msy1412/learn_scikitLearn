# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
import numpy as np 
from sklearn.tree import DecisionTreeRegressor 
import matplotlib.pyplot as plt

# %%
Boston = load_boston()

# %%
reg = DecisionTreeRegressor(random_state=0)

# %%
cross_val_score(reg,Boston.data,Boston.target,cv=10)
# Out:
# array([ 0.52939335,  0.60461936, -1.60907519,  0.4356399 ,  0.77280671,
#         0.40597035,  0.23656049,  0.38709149, -2.06488186, -0.95162992])

# %%
rng = np.random.RandomState(1)#随机数种子
X = np.sort(5 * rng.rand(80,1), axis=0)#生成0~5间得随机得x取值
y = np.sin(X).ravel()#生成正弦曲线

# %%
plt.figure() 
plt.scatter(X, y, s=20, edgecolor="black",c="darkorange", label="data")

# %%
y[::5] += 3 * (0.5 - rng.rand(16))#切片加误差

# %%
plt.figure() 
plt.scatter(X, y, s=20, edgecolor="black",c="darkorange", label="data")

# %%
regr_1 = DecisionTreeRegressor(max_depth=2) 
regr_2 = DecisionTreeRegressor(max_depth=5) 
regr_1.fit(X, y) 
regr_2.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
test_x = np.arange(0.0,5.0,0.01)[:,np.newaxis]

# %%
test_x.shape
# Out:
# (500, 1)

# %%
y_1 = regr_1.predict(test_x) 
y_2 = regr_2.predict(test_x)

# %%
plt.figure() 
plt.scatter(X, y, s=20, edgecolor="black",c="darkorange", label="data") 
plt.plot(test_x, y_1, color="cornflowerblue",label="max_depth=2", linewidth=2) 
plt.plot(test_x, y_2, color="yellowgreen", label="max_depth=5", linewidth=2) 
plt.xlabel("data") 
plt.ylabel("target") 
plt.title("Decision Tree Regression") 
plt.legend() 
plt.show()

# %%
#最大深度5时出现过拟合
